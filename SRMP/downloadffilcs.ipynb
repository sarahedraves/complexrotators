# %%
import numpy as np
import pandas as pd
import lightkurve as lk
# %run ../pipeline.ipynb

# %%
df = pd.read_csv(
    "NIMO_lcnames.csv",
    dtype={
        "TIC": "string",
        "gaiadr3_source_id": "string",
    },
)
df.head()
# Out:
#    nimo_id        TIC    gaiadr3_source_id group  num_sectors  Sector  \
# 0        1  350559457  4767439021687332096   car           45       1
# 1        1  350559457  4767439021687332096   car           45       2
# 2        1  350559457  4767439021687332096   car           45       3
# 3        1  350559457  4767439021687332096   car           45       4
# 4        1  350559457  4767439021687332096   car           45       5
#
#        name                   lc_name
# 0  SPOC-120  TIC-350559457-1-SPOC-120
# 1  SPOC-120  TIC-350559457-2-SPOC-120
# 2  SPOC-120  TIC-350559457-3-SPOC-120
# 3  SPOC-120  TIC-350559457-4-SPOC-120
# 4  SPOC-120  TIC-350559457-5-SPOC-120

# %%
DOWNLOAD_PATH = "../data"
LIGHTCURVE_PATH = "../lightcurves"

# %%
for index, row in df.iterrows():
    if 'FFI' in row['lc_name']:
        print(row['lc_name'])
        get_lc_string(row['lc_name'])
# Out:
# TIC-24604498-6-FFI-30min
# TIC-158817023-6-FFI-30min
# TIC-345772521-6-FFI-30min
# TIC-311272948-6-FFI-30min
# TIC-200001428-6-FFI-30min
# TIC-345773622-6-FFI-30min
# TIC-389248164-6-FFI-30min
# TIC-264461317-6-FFI-30min
# TIC-389248318-6-FFI-30min
# TIC-365692367-6-FFI-30min
# TIC-365744968-6-FFI-30min
# TIC-365747298-6-FFI-30min
# TIC-302417241-6-FFI-30min
# TIC-302417238-6-FFI-30min
# TIC-365782379-6-FFI-30min
# TIC-264679930-6-FFI-30min
# TIC-138901588-6-FFI-30min
# TIC-52583022-6-FFI-30min
# TIC-50745533-6-FFI-30min
# TIC-436103626-6-FFI-30min
# TIC-29847084-9-FFI-30min
# TIC-188172972-9-FFI-30min
# TIC-54147487-9-FFI-30min
# TIC-102462453-9-FFI-30min
# TIC-429152614-10-FFI-30min
# TIC-29847084-10-FFI-30min
# TIC-429152610-10-FFI-30min
# TIC-144221008-10-FFI-30min
# TIC-144221039-10-FFI-30min
# TIC-134976537-10-FFI-30min
# TIC-404012628-10-FFI-30min
# TIC-91474691-10-FFI-30min
# TIC-102462453-10-FFI-30min
# TIC-360558208-11-FFI-30min
# TIC-327549481-11-FFI-30min
# ...
