# %%
import numpy as np
import pandas as pd
import lightkurve as lk 
import matplotlib.pyplot as plt
import astropy.table as tb
from astropy.io import ascii
import re

# %%
pd.options.display.max_columns = None

# %%
tics=ascii.read('ticresults.dat')
epics=ascii.read('epicresults.dat')

# %%
dtypes={'pop_id':'string','TIC':'string','gaiadr3_source_id':'string','epic_id':'string'}
id_table=pd.read_csv('idswithdiscopaper.csv',dtype=dtypes)

# %%
id_table=id_table[['pop_id','TIC','gaiadr3_source_id','per','epic_id','disco_paper','author','year']]

# %%
id_table['tess_sectors']=""
id_table['K2_campaign']=""

# %%
id_table['TIC']=id_table['TIC'].astype('Int64').astype('string')
id_table['epic_id']=id_table['epic_id'].astype('Int64').astype('string')

# %%
id_table
# Out:
#     pop_id        TIC    gaiadr3_source_id        per    epic_id  \
# 0        0   59129133  3392549449695395968   0.625300  246676629
# 1        1   59091144  3392553852037339776   0.437700  246682490
# 2        2  118769116  3411342134934571520   0.356800  247343526
# 3        3  175594111  6045818685674325760   0.599300  203354381
# 4        4  322928171  6048612514663537280   0.779400  203636498
# ..     ...        ...                  ...        ...        ...
# 203    203  301676454  3795298673460008064   0.382500       <NA>
# 204    204   58084670  2034818379464853376   0.465000       <NA>
# 205    205   67745212  3191994547355916288   0.213333       <NA>
# 206    206    5714469  3493814268751183744   0.431250       <NA>
# 207    207  259586708  4784133288986121728  22.520000       <NA>
#
#        disco_paper    author  year tess_sectors K2_campaign
# 0    Stauffer_2018  Stauffer  2018
# 1    Stauffer_2018  Stauffer  2018
# 2    Stauffer_2018  Stauffer  2018
# 3    Stauffer_2018  Stauffer  2018
# 4    Stauffer_2018  Stauffer  2018
# ..             ...       ...   ...          ...         ...
# 203     Bouma_2024     Bouma  2024
# 204     Bouma_2024     Bouma  2024
# 205     Bouma_2024     Bouma  2024
# 206     Bouma_2024     Bouma  2024
# 207     Bouma_2024     Bouma  2024
#
# [208 rows x 10 columns]

# %%
ticdf=tics.to_pandas()

# %%
for index, row in id_table.iterrows():
    curtic=row['TIC']
    if pd.isna(curtic):
        continue
    sectorlist=""
    for index2, row2 in ticdf.iterrows():
        if row2['target_name']==curtic:
            sectorlist=sectorlist+row2['mission']+" "+row2['project_products']+" "+str(row2['exptime'])+"s "
    id_table.at[index,'tess_sectors']=sectorlist

# %%
id_table
# Out:
#     pop_id        TIC    gaiadr3_source_id        per    epic_id  \
# 0        0   59129133  3392549449695395968   0.625300  246676629
# 1        1   59091144  3392553852037339776   0.437700  246682490
# 2        2  118769116  3411342134934571520   0.356800  247343526
# 3        3  175594111  6045818685674325760   0.599300  203354381
# 4        4  322928171  6048612514663537280   0.779400  203636498
# ..     ...        ...                  ...        ...        ...
# 203    203  301676454  3795298673460008064   0.382500       <NA>
# 204    204   58084670  2034818379464853376   0.465000       <NA>
# 205    205   67745212  3191994547355916288   0.213333       <NA>
# 206    206    5714469  3493814268751183744   0.431250       <NA>
# 207    207  259586708  4784133288986121728  22.520000       <NA>
#
#        disco_paper    author  year  \
# 0    Stauffer_2018  Stauffer  2018
# 1    Stauffer_2018  Stauffer  2018
# 2    Stauffer_2018  Stauffer  2018
# 3    Stauffer_2018  Stauffer  2018
# 4    Stauffer_2018  Stauffer  2018
# ..             ...       ...   ...
# 203     Bouma_2024     Bouma  2024
# 204     Bouma_2024     Bouma  2024
# 205     Bouma_2024     Bouma  2024
# 206     Bouma_2024     Bouma  2024
# 207     Bouma_2024     Bouma  2024
#
#                                           tess_sectors K2_campaign
# 0    TESS Sector 43 SPOC 120s TESS Sector 44 SPOC 1...
# 1    TESS Sector 43 SPOC 120s TESS Sector 44 SPOC 1...
# 2    TESS Sector 43 SPOC 120s TESS Sector 44 SPOC 1...
# 3    TESS Sector 91 SPOC 120s TESS Sector 91 QLP 200s
# 4                            TESS Sector 91 SPOC 120s
# ..                                                 ...         ...
# 203  TESS Sector 46 SPOC 120s TESS Sector 46 TESS-S...
# 204  TESS Sector 41 SPOC 120s TESS Sector 55 SPOC 1...
# 205  TESS Sector 32 SPOC 120s TESS Sector 05 TESS-S...
# 206  TESS Sector 10 SPOC 120s TESS Sector 90 SPOC 1...
# 207  TESS Sector 06 SPOC 120s TESS Sector 05 SPOC 1...
#
# [208 rows x 10 columns]

# %%
epicdf=epics.to_pandas()

# %%
for index, row in id_table.iterrows():
    curepic=row['epic_id']
    if pd.isna(curepic):
        continue
    camplist=""
    for index2, row2 in epicdf.iterrows():
        if re.sub(r'^\D+', '', row2['target_name'])==curepic:
            camplist=camplist+row2['mission']+" "+row2['project_products']+" "+str(row2['exptime'])+"s "
    id_table.at[index,'K2_campaign']=camplist

# %%
id_table
# Out:
#     pop_id        TIC    gaiadr3_source_id        per    epic_id  \
# 0        0   59129133  3392549449695395968   0.625300  246676629
# 1        1   59091144  3392553852037339776   0.437700  246682490
# 2        2  118769116  3411342134934571520   0.356800  247343526
# 3        3  175594111  6045818685674325760   0.599300  203354381
# 4        4  322928171  6048612514663537280   0.779400  203636498
# ..     ...        ...                  ...        ...        ...
# 203    203  301676454  3795298673460008064   0.382500       <NA>
# 204    204   58084670  2034818379464853376   0.465000       <NA>
# 205    205   67745212  3191994547355916288   0.213333       <NA>
# 206    206    5714469  3493814268751183744   0.431250       <NA>
# 207    207  259586708  4784133288986121728  22.520000       <NA>
#
#        disco_paper    author  year  \
# 0    Stauffer_2018  Stauffer  2018
# 1    Stauffer_2018  Stauffer  2018
# 2    Stauffer_2018  Stauffer  2018
# 3    Stauffer_2018  Stauffer  2018
# 4    Stauffer_2018  Stauffer  2018
# ..             ...       ...   ...
# 203     Bouma_2024     Bouma  2024
# 204     Bouma_2024     Bouma  2024
# 205     Bouma_2024     Bouma  2024
# 206     Bouma_2024     Bouma  2024
# 207     Bouma_2024     Bouma  2024
#
#                                           tess_sectors  \
# 0    TESS Sector 43 SPOC 120s TESS Sector 44 SPOC 1...
# 1    TESS Sector 43 SPOC 120s TESS Sector 44 SPOC 1...
# 2    TESS Sector 43 SPOC 120s TESS Sector 44 SPOC 1...
# 3    TESS Sector 91 SPOC 120s TESS Sector 91 QLP 200s
# 4                            TESS Sector 91 SPOC 120s
# ..                                                 ...
# 203  TESS Sector 46 SPOC 120s TESS Sector 46 TESS-S...
# 204  TESS Sector 41 SPOC 120s TESS Sector 55 SPOC 1...
# 205  TESS Sector 32 SPOC 120s TESS Sector 05 TESS-S...
# 206  TESS Sector 10 SPOC 120s TESS Sector 90 SPOC 1...
# 207  TESS Sector 06 SPOC 120s TESS Sector 05 SPOC 1...
#
#                                            K2_campaign
# 0    K2 Campaign 13 K2 1800s K2 Campaign 13 EVEREST...
# 1    K2 Campaign 13 K2 1800s K2 Campaign 13 EVEREST...
# 2    K2 Campaign 13 K2 1800s K2 Campaign 13 EVEREST...
# 3    K2 Campaign 02 K2 1800s K2 Campaign 02 EVEREST...
# 4    K2 Campaign 02 K2 1800s K2 Campaign 02 EVEREST...
# ..                                                 ...
# 203
# 204
# 205
# 206
# 207
#
# [208 rows x 10 columns]

# %%
id_table.to_csv('availablelightcurves.csv', index=False)

# %%
ffis=pd.read_csv('tesstimes.csv',header=None)

# %%
ffis=ffis.astype(str)

# %%
np.unique(ffis.values.ravel(),return_counts=True)
# Out:
# (array(['0.0', '1425.6', '158.4', '475.2'], dtype=object),
#  array([19938,   222,   343,   297]))

# %%
#replace exposure times with cadence type
for row in range(ffis.shape[0]):
    for col in range(ffis.shape[1]):
        value=ffis.iat[row,col]
        if value=='158.4':
            ffis.iat[row,col]='200s'
        elif value=='475.2':
            ffis.iat[row,col]='10min'
        elif value=='1425.6':
            ffis.iat[row,col]='30min'
        else:
            ffis.iat[row,col]='none'

# %%
#ffis

# %%
np.unique(ffis.values.ravel(), return_counts=True) #counts of each match above so that's good
# Out:
# (array(['10min', '200s', '30min', 'none'], dtype=object),
#  array([  297,   343,   222, 19938]))

# %%
ticdf=ticdf[ticdf['project']=='TESS'] #drop kepler observations

# %%
ticdf=ticdf[ticdf['exptime']==120] #only the 2min postage stamp cadences

# %%
ticdf['provenance_name'].unique()
# Out:
# array(['SPOC', 'TASOC'], dtype=object)

# %%
ticdf=ticdf[ticdf['provenance_name'].str.contains('SPOC')] #drop lightcurve types we don't like

# %%
ticdf['sector']=ticdf['mission'].str.extract(r'(\d+)').astype(int)

# %%
#ticdf

# %%
bestTESSlc=pd.DataFrame([[''] * ffis.shape[1] for _ in range(ffis.shape[0])])
bestTESSlc.columns = [f'Sector {i}' for i in range(ffis.shape[1])]

# %%
#needs to be in format id_type-starid-secorcamp-author-exptime so get_lc fn can work on it
for curTIC, row in zip(id_table['TIC'],range(bestTESSlc.shape[0])):
    if pd.isna(curTIC):
        continue
    for col in range(bestTESSlc.shape[1]): #remember that col is the sector number we're considering here
        bestcurve=''
        #first check if there's a SPOC curve for it
        for index2, row2 in ticdf.iterrows():
            if row2['target_name']==curTIC and row2['sector']==col:
                bestcurve='TIC'+'-'+curTIC+'-'+str(col)+'-'+row2['provenance_name']+'-'+str(row2['exptime'])
        #if it didn't find a postage stamp lightcurve for this sector get the FFI info
        if bestcurve=='': 
            exptime=ffis.iat[row,col]
            if exptime!='none':
                bestcurve='TIC'+'-'+curTIC+'-'+str(col)+'-FFI-'+exptime
        bestTESSlc.iat[row,col]=bestcurve

# %%
bestTESSlc
# Out:
#     Sector 0 Sector 1 Sector 2                  Sector 3  \
# 0
# 1
# 2
# 3
# 4
# ..       ...      ...      ...                       ...
# 203
# 204
# 205
# 206
# 207                             TIC-259586708-3-SPOC-120
#
#                      Sector 4                  Sector 5  \
# 0                              TIC-59129133-5-FFI-30min
# 1                              TIC-59091144-5-FFI-30min
# 2
# 3
# 4
# ..                        ...                       ...
# 203
# 204
# 205                            TIC-67745212-5-FFI-30min
# 206
# 207  TIC-259586708-4-SPOC-120  TIC-259586708-5-SPOC-120
#
#                      Sector 6 Sector 7 Sector 8 Sector 9  \
# 0
# 1
# 2
# 3
# 4
# ..                        ...      ...      ...      ...
# 203
# 204
# 205
# 206
# 207  TIC-259586708-6-SPOC-120
#
#                    Sector 10 Sector 11 Sector 12 Sector 13  \
# 0
# 1
# 2
# 3
# 4
# ..                       ...       ...       ...       ...
# 203
# 204
# 205
# 206  TIC-5714469-10-SPOC-120
# 207
#
#                      Sector 14 Sector 15 Sector 16 Sector 17 Sector 18  \
# 0
# 1
# 2
# 3
# 4
# ..                         ...       ...       ...       ...       ...
# 203
# 204  TIC-58084670-14-FFI-30min
# 205
# 206
# 207
#
#     Sector 19 Sector 20 Sector 21 Sector 22 Sector 23 Sector 24 Sector 25  \
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...       ...       ...       ...       ...       ...
# 203
# 204
# 205
# 206
# 207
#
#     Sector 26 Sector 27 Sector 28 Sector 29                  Sector 30  \
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...       ...       ...                        ...
# 203
# 204
# 205
# 206
# 207                                          TIC-259586708-30-SPOC-120
#
#                      Sector 31                  Sector 32 Sector 33 Sector 34  \
# 0                               TIC-59129133-32-FFI-10min
# 1                               TIC-59091144-32-FFI-10min
# 2
# 3
# 4
# ..                         ...                        ...       ...       ...
# 203
# 204
# 205                              TIC-67745212-32-SPOC-120
# 206
# 207  TIC-259586708-31-SPOC-120  TIC-259586708-32-SPOC-120
#
#     Sector 35                 Sector 36 Sector 37 Sector 38 Sector 39  \
# 0
# 1
# 2
# 3
# 4
# ..        ...                       ...       ...       ...       ...
# 203
# 204
# 205
# 206            TIC-5714469-36-FFI-10min
# 207
#
#     Sector 40                 Sector 41 Sector 42                  Sector 43  \
# 0                                                   TIC-59129133-43-SPOC-120
# 1                                                   TIC-59091144-43-SPOC-120
# 2                                                  TIC-118769116-43-SPOC-120
# 3
# 4
# ..        ...                       ...       ...                        ...
# 203
# 204            TIC-58084670-41-SPOC-120
# 205
# 206
# 207
#
#                      Sector 44 Sector 45                  Sector 46 Sector 47  \
# 0     TIC-59129133-44-SPOC-120
# 1     TIC-59091144-44-SPOC-120
# 2    TIC-118769116-44-SPOC-120
# 3
# 4
# ..                         ...       ...                        ...       ...
# 203                                       TIC-301676454-46-SPOC-120
# 204
# 205
# 206
# 207
#
#     Sector 48 Sector 49 Sector 50 Sector 51 Sector 52 Sector 53  \
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...       ...       ...       ...       ...
# 203
# 204
# 205
# 206
# 207
#
#                     Sector 54                 Sector 55 Sector 56 Sector 57  \
# 0
# 1
# 2
# 3
# 4
# ..                        ...                       ...       ...       ...
# 203
# 204  TIC-58084670-54-SPOC-120  TIC-58084670-55-SPOC-120
# 205
# 206
# 207
#
#     Sector 58 Sector 59 Sector 60 Sector 61 Sector 62  \
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...       ...       ...       ...
# 203
# 204
# 205
# 206
# 207
#
#                    Sector 63 Sector 64 Sector 65 Sector 66 Sector 67  \
# 0
# 1
# 2
# 3
# 4
# ..                       ...       ...       ...       ...       ...
# 203
# 204
# 205
# 206  TIC-5714469-63-FFI-200s
# 207
#
#     Sector 68 Sector 69                  Sector 70                  Sector 71  \
# 0                                                    TIC-59129133-71-FFI-200s
# 1                                                    TIC-59091144-71-FFI-200s
# 2                        TIC-118769116-70-FFI-200s  TIC-118769116-71-FFI-200s
# 3
# 4
# ..        ...       ...                        ...                        ...
# 203
# 204
# 205
# 206
# 207
#
#                      Sector 72 Sector 73                 Sector 74  \
# 0
# 1
# 2
# 3
# 4
# ..                         ...       ...                       ...
# 203  TIC-301676454-72-FFI-200s
# 204                                       TIC-58084670-74-SPOC-120
# 205
# 206
# 207
#
#                     Sector 75 Sector 76 Sector 77 Sector 78 Sector 79  \
# 0
# 1
# 2
# 3
# 4
# ..                        ...       ...       ...       ...       ...
# 203
# 204  TIC-58084670-75-SPOC-120
# 205
# 206
# 207
#
#     Sector 80                 Sector 81 Sector 82 Sector 83 Sector 84  \
# 0
# 1
# 2
# 3
# 4
# ..        ...                       ...       ...       ...       ...
# 203
# 204            TIC-58084670-81-SPOC-120
# 205
# 206
# 207
#
#     Sector 85 Sector 86 Sector 87 Sector 88 Sector 89  \
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...       ...       ...       ...
# 203
# 204
# 205
# 206
# 207
#
#                    Sector 90                  Sector 91 Sector 92 Sector 93  \
# 0
# 1
# 2
# 3                             TIC-175594111-91-SPOC-120
# 4                             TIC-322928171-91-SPOC-120
# ..                       ...                        ...       ...       ...
# 203
# 204
# 205
# 206  TIC-5714469-90-SPOC-120
# 207
#
#     Sector 94 Sector 95 Sector 96 Sector 97 Sector 98 Sector 99
# 0
# 1
# 2
# 3
# 4
# ..        ...       ...       ...       ...       ...       ...
# 203
# 204
# 205
# 206
# 207
#
# [208 rows x 100 columns]

# %%
bestTESSlc.to_csv('bestTESSlc.csv')

# %%
epicdf=epicdf[epicdf['project']=='K2']
epicdf=epicdf[epicdf['provenance_name']=='EVEREST']
epicdf['campaign']=epicdf['mission'].str.extract(r'(\d+)$').astype(int)

# %%
maxcampaign=epicdf['campaign'].max()+1

# %%
bestK2lc=pd.DataFrame([[''] * maxcampaign for _ in range(ffis.shape[0])])
bestK2lc.columns = [f'Campaign {i}' for i in range(maxcampaign)]

# %%
bestK2lc
# Out:
#     Campaign 0 Campaign 1 Campaign 2 Campaign 3 Campaign 4 Campaign 5  \
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...        ...        ...
# 203
# 204
# 205
# 206
# 207
#
#     Campaign 6 Campaign 7 Campaign 8 Campaign 9 Campaign 10 Campaign 11  \
# 0
# 1
# 2
# 3
# 4
# ..         ...        ...        ...        ...         ...         ...
# 203
# 204
# 205
# 206
# 207
#
#     Campaign 12 Campaign 13 Campaign 14 Campaign 15
# 0
# 1
# 2
# 3
# 4
# ..          ...         ...         ...         ...
# 203
# 204
# 205
# 206
# 207
#
# [208 rows x 16 columns]

# %%
for curepic, row in zip(id_table['epic_id'],range(bestK2lc.shape[0])):
    if pd.isna(curepic):
        continue
    for col in range(bestK2lc.shape[1]): #remember that col is the campaign number we're considering here
        bestcurve=''
        #find EVEREST LC data
        for index2, row2 in epicdf.iterrows():
            if re.sub(r'^\D+', '', row2['target_name'])==curepic and row2['campaign']==col:
                bestcurve='EPIC'+'-'+curepic+'-'+str(col)+'-'+row2['provenance_name']+'-'+str(row2['exptime'])
        bestK2lc.iat[row,col]=bestcurve

# %%
bestK2lc.to_csv('bestK2lc.csv')

# %%
#make list of strings for the K2SFF author instead
K2SFFlist=np.array([],dtype='object')

# %%
epicdfunfilt=epics.to_pandas()
#epicdfunfilt

# %%
for index, currow in epicdfunfilt.iterrows():
    if currow['provenance_name']=='K2SFF':
        epicid=re.sub(r'^\D+', '', currow['target_name']).lstrip('0')
        campaign=int(re.search(r'\d+$', currow['mission']).group()) #have to cast to int and back to get rid of the leading zeros
        pop_id=id_table.loc[id_table['epic_id']==epicid, 'pop_id'].values[0]
        bestcurve=pop_id+'_EPIC'+'-'+epicid+'-'+str(campaign)+'-'+currow['provenance_name']+'-'+str(currow['exptime'])
        K2SFFlist=np.append(K2SFFlist,bestcurve)

# %%
np.savetxt('K2SFFlist.txt', K2SFFlist, fmt='%s')
