# %%
import numpy as np
import pandas as pd

# %%
dtypes={'pop_id':'string','TIC':'string','gaiadr3_source_id':'string','epic_id':'string'}

# %%
df=pd.read_csv('Full_complex_sarah - Objects and References.csv',dtype=dtypes)

# %%
idtable=df[['pop_id','TIC','gaiadr3_source_id','epic_id','per','per2','group','age_Myr']]

# %%
papertable=df.drop(columns=['pop_id','TIC','gaiadr3_source_id','epic_id','per'])

# %%
idtable['disco_paper']=""
# Out:
# /var/folders/zd/14hqhh8n6v122yj77t47nyv40000gn/T/ipykernel_90672/2757942557.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idtable['disco_paper']=""

# %%
for index, idrow in idtable.iterrows():
    paperrow=papertable.loc[index]
    for papercol in papertable.columns:
        value=paperrow[papercol]
        if value=='First CR determination':
            idtable.at[index,'disco_paper']=papercol

# %%
idtable
# Out:
#     pop_id        TIC    gaiadr3_source_id    epic_id       per    per2  \
# 0        0   59129133  3392549449695395968  246676629  0.625300  0.6332
# 1        1   59091144  3392553852037339776  246682490  0.437700  3.6324
# 2        2  118769116  3411342134934571520  247343526  0.356800     NaN
# 3        3  175594111  6045818685674325760  203354381  0.599300     NaN
# 4        4  322928171  6048612514663537280  203636498  0.779400     NaN
# ..     ...        ...                  ...        ...       ...     ...
# 194    207  259586708  4784133288986121728       <NA>  0.938333     NaN
# 195    208  245902096  3309889784723415168  246776923  0.637500  0.5551
# 196    209  245874053                 <NA>  246938594  1.083900     NaN
# 197    210  245868207  3313414750283302400  246969828  1.006300  1.2995
# 198    211  268324578   147799209159857280  247794636  1.721100  2.6225
#
#                  group  age_Myr    disco_paper
# 0               Taurus      2.0  Stauffer_2018
# 1               Taurus      2.0  Stauffer_2018
# 2               Taurus      2.0  Stauffer_2018
# 3       Upper Scorpius     10.0  Stauffer_2018
# 4       Upper Scorpius     10.0  Stauffer_2018
# ..                 ...      ...            ...
# 194            Columba     42.0     Bouma_2024
# 195  Taurus Foreground     30.0    Rebull_2020
# 196             Taurus      2.0    Rebull_2020
# 197             Taurus      2.0    Rebull_2020
# 198             Taurus      2.0    Rebull_2020
#
# [199 rows x 9 columns]

# %%
idtable[['author', 'year']] = idtable['disco_paper'].str.split('_', expand=True)
# Out:
# /var/folders/zd/14hqhh8n6v122yj77t47nyv40000gn/T/ipykernel_90672/274077772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idtable[['author', 'year']] = idtable['disco_paper'].str.split('_', expand=True)
# /var/folders/zd/14hqhh8n6v122yj77t47nyv40000gn/T/ipykernel_90672/274077772.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   idtable[['author', 'year']] = idtable['disco_paper'].str.split('_', expand=True)

# %%
idtable.to_csv('idswithdiscopaper.csv', index=False)

# %%
gaiaonly=idtable[idtable['gaiadr3_source_id']!='']

# %%
gaiaonly.to_csv('ourgaiaids.csv', index=False)
