# %%
import os
import uuid
import shutil
#import pylatex
import pandas as pd
import lightkurve as lk 
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

from datetime import datetime
from tqdm.notebook import tqdm
from multiprocessing import cpu_count, Pool
#from pylatex.section import Chapter, Subsection
#from pylatex import Document, Section, Figure, NoEscape, Command

# %run pipeline.ipynb

import warnings
warnings.filterwarnings("ignore")

# %%
gaiatable=pd.read_csv('makingtable/cleanedgaiadata.csv')

# %%
mylc=get_lc_string('TIC-59129133-43-SPOC-120')
mylc2=get_lc_string('TIC-59129133-5-FFI-30min')
mylc3=get_lc_string('EPIC-246676629-13-EVEREST-1800')

# %%
multiplot3(mylc,'TIC-59129133-43-SPOC-120',gaiatable)

# %%
multiplot3(mylc2,'TIC-59129133-5-FFI-30min',gaiatable)

# %%
multiplot3(mylc3,'EPIC-246676629-13-EVEREST-1800',gaiatable)

# %%
#mylc2.flux=mylc2.flux+1

# %%
#mylc2

# %%
mylc4=get_lc_string('TIC-175743566-91-SPOC-120')

# %%
multiplot3(mylc4,'TIC-175743566-91-SPOC-120',gaiatable)

# %%
mylc5=get_lc_string('TIC-442571495-91-FFI-200s')

# %%
multiplot3(mylc5,'TIC-442571495-91-FFI-200s',gaiatable)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 multiplot3(mylc5,'TIC-442571495-91-FFI-200s',gaiatable)
#
# File /var/folders/zd/14hqhh8n6v122yj77t47nyv40000gn/T/ipykernel_8843/897655914.py:27, in multiplot3(lc, infostring, gaiatable, period, bintime)
#      13 fig, axs = plt.subplot_mosaic([
#      14     ['11','11','11','14'],
#      15     ['11','11','11','14'],
#    (...)
#      23     ['91','91','91','91']
#      24 ], figsize=(10,16), layout="constrained")
#      26 if period==None:
# ---> 27     period = lc.to_periodogram(maximum_period=5).period_at_max_power
#      28 if bintime==None:
#      29     bintime=u.Quantity(period/200,u.s)
#
# File /opt/anaconda3/envs/bdnyc/lib/python3.12/site-packages/lightkurve/lightcurve.py:2375, in LightCurve.to_periodogram(self, method, **kwargs)
#    2372 else:
#    2373     from .periodogram import LombScarglePeriodogram
# -> 2375     return LombScarglePeriodogram.from_lightcurve(lc=self, **kwargs)
#
# File /opt/anaconda3/envs/bdnyc/lib/python3.12/site-packages/lightkurve/periodogram.py:850, in LombScarglePeriodogram.from_lightcurve(lc, minimum_frequency, maximum_frequency, minimum_period, maximum_period, frequency, period, nterms, nyquist_factor, oversample_factor, freq_unit, normalization, ls_method, **kwargs)
#     848 # Approximate Nyquist Frequency and frequency bin width in terms of days
#     849 nyquist = 0.5 * (1.0 / (np.median(np.diff(time.value)))) * (1 / cds.d)
# --> 850 fs = (1.0 / (time[-1] - time[0])) / oversample_factor
#     852 # Convert these values to requested frequency unit
#     853 nyquist = nyquist.to(freq_unit)
#
# File /opt/anaconda3/envs/bdnyc/lib/python3.12/site-packages/astropy/utils/shapes.py:234, in ShapedLikeNDArray.__getitem__(self, item)
#     232 def __getitem__(self, item):
#     233     try:
# --> 234         return self._apply("__getitem__", item)
#     235     except IndexError:
#     236         if self.isscalar:
#
# File /opt/anaconda3/envs/bdnyc/lib/python3.12/site-packages/astropy/time/core.py:1394, in TimeBase._apply(self, method, format, cls, *args, **kwargs)
#    1392 jd1, jd2 = self._time.jd1, self._time.jd2
#    1393 if apply_method:
# -> 1394     jd1 = apply_method(jd1)
#    1395     jd2 = apply_method(jd2)
#    1397 # Get a new instance of our class and set its attributes directly.
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
