# %%
import numpy as np
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
id_table=pd.read_csv('makingtable/idswithdiscopaper.csv')
bestlcs=pd.read_csv('makingtable/bestlcs.csv')

# %%
id_table["epic_id"].notna().sum() #number that have epic ids
# Out:
# 64

# %%
mask1=id_table["epic_id"].notna()

# %%
filteredids=id_table[mask1]

# %%
start_col=bestlcs.columns.get_loc('Campaign 1')

# %%
campaign_cols=[]

# %%
for col in bestlcs.columns[start_col:]:
    campaign_cols.append(col)

# %%
bestlcs[campaign_cols].notna().any(axis=1).sum()
# Out:
# 62

# %%
mask2=bestlcs[campaign_cols].notna().any(axis=1)

# %%
filteredlcs=bestlcs[mask2]

# %%
# Convert columns to sets
set1 = set(filteredids["pop_id"].dropna())
set2 = set(filteredlcs["pop_id"].dropna())

# Find values unique to each
only_in_col1 = set1 - set2
only_in_col2 = set2 - set1

print(f"Values only in col1: {only_in_col1}")
print(f"Values only in col2: {only_in_col2}")
# Out:
# Values only in col1: {201, 187}
# Values only in col2: set()

# %%
# Count non-NaNs per row
notna_counts = bestlcs[campaign_cols].notna().sum(axis=1)

# Create mask for rows with 2 or more non-NaNs
mask3 = notna_counts >= 2

# Filter DataFrame
filtered2 = bestlcs[mask3]
filtered2
# Out:
#      pop_id         TIC  gaiadr3_source_id      epic_id     per  \
# 15       15  12659333.0       6.237069e+18  204066898.0  0.3956
# 129     129  12779416.0                NaN  204364515.0  1.4560
# 143     143  12776845.0       6.237181e+18  204270520.0  0.5123
#
#               group  age_Myr    disco_paper    author  paper_year  ...  \
# 15   Upper Scorpius     10.0  Stauffer_2017  Stauffer        2017  ...
# 129  Upper Scorpius     10.0  Stauffer_2017  Stauffer        2017  ...
# 143  Upper Scorpius     10.0    Rebull_2018    Rebull        2018  ...
#
#     Campaign 6 Campaign 7 Campaign 8 Campaign 9 Campaign 10 Campaign 11  \
# 15         NaN        NaN        NaN        NaN         NaN         NaN
# 129        NaN        NaN        NaN        NaN         NaN         NaN
# 143        NaN        NaN        NaN        NaN         NaN         NaN
#
#     Campaign 12 Campaign 13 Campaign 14                     Campaign 15
# 15          NaN         NaN         NaN  EPIC-204066898-15-EVEREST-1800
# 129         NaN         NaN         NaN  EPIC-204364515-15-EVEREST-1800
# 143         NaN         NaN         NaN  EPIC-204270520-15-EVEREST-1800
#
# [3 rows x 124 columns]

# %%
start_col=bestlcs.columns.get_loc('Sector 1')
end_col=bestlcs.columns.get_loc('Sector 99')
sector_cols=[]
for col in bestlcs.columns[start_col:end_col]:
    sector_cols.append(col)

# %%
mask4=bestlcs[sector_cols].notna().any(axis=1)

# %%
bestlcs[np.logical_not(mask4)]
# Out:
#      pop_id          TIC  gaiadr3_source_id      epic_id     per  \
# 19       19  220765024.0       6.246945e+18  204918279.0  0.4665
# 196     196          NaN       3.308598e+18  246650193.0  2.9245
#
#               group  age_Myr    disco_paper    author  paper_year  ...  \
# 19   Upper Scorpius     10.0  Stauffer_2017  Stauffer        2017  ...
# 196           Field      NaN    Rebull_2020    Rebull        2020  ...
#
#     Campaign 6 Campaign 7 Campaign 8 Campaign 9 Campaign 10 Campaign 11  \
# 19         NaN        NaN        NaN        NaN         NaN         NaN
# 196        NaN        NaN        NaN        NaN         NaN         NaN
#
#     Campaign 12                     Campaign 13 Campaign 14 Campaign 15
# 19          NaN                             NaN         NaN         NaN
# 196         NaN  EPIC-246650193-13-EVEREST-1800         NaN         NaN
#
# [2 rows x 124 columns]

# %%
bestlcsfilt=bestlcs.drop([19,196])

# %%
mask5 = bestlcsfilt[sector_cols].astype(str).apply(lambda col: col.str.contains('FFI', na=False))

# %%
match_counts = mask5.sum(axis=1)

# %%
bestlcsfilt[match_counts >= 1]
# Out:
#      pop_id          TIC  gaiadr3_source_id      epic_id       per  \
# 0         0   59129133.0       3.392549e+18  246676629.0  0.625300
# 1         1   59091144.0       3.392554e+18  246682490.0  3.632400
# 2         2  118769116.0       3.411342e+18  247343526.0  0.356800
# 9         9   48908525.0       6.242106e+18  204099739.0  0.742800
# 21       21  280945693.0       5.234117e+18          NaN  0.636300
# ..      ...          ...                ...          ...       ...
# 201     201  244161191.0       2.431769e+18   60019763.0  0.298750
# 203     203  301676454.0       3.795299e+18          NaN  0.382500
# 204     204   58084670.0       2.034818e+18          NaN  0.465000
# 205     205   67745212.0       3.191995e+18          NaN  0.213333
# 206     206    5714469.0       3.493814e+18          NaN  0.431250
#
#                      group  age_Myr    disco_paper    author  paper_year  \
# 0                   Taurus      2.0  Stauffer_2018  Stauffer        2018
# 1                   Taurus      2.0  Stauffer_2018  Stauffer        2018
# 2                   Taurus      2.0  Stauffer_2018  Stauffer        2018
# 9           Upper Scorpius     10.0  Stauffer_2018  Stauffer        2018
# 21    Lower Centaurus-Crux     16.0  Stauffer_2021  Stauffer        2021
# ..                     ...      ...            ...       ...         ...
# 201                Columba     42.0     Bouma_2024     Bouma        2024
# 203                  Argus     45.0     Bouma_2024     Bouma        2024
# 204                  Field      NaN     Bouma_2024     Bouma        2024
# 205                Columba     42.0     Bouma_2024     Bouma        2024
# 206  Upper Centaurus-Lupus     16.0     Bouma_2024     Bouma        2024
#
#     Sector 1 Sector 2                  Sector 3 Sector 4  \
# 0        NaN      NaN                       NaN      NaN
# 1        NaN      NaN                       NaN      NaN
# 2        NaN      NaN                       NaN      NaN
# 9        NaN      NaN                       NaN      NaN
# 21       NaN      NaN                       NaN      NaN
# ..       ...      ...                       ...      ...
# 201      NaN      NaN  TIC-244161191-3-SPOC-120      NaN
# 203      NaN      NaN                       NaN      NaN
# 204      NaN      NaN                       NaN      NaN
# 205      NaN      NaN                       NaN      NaN
# 206      NaN      NaN                       NaN      NaN
#
#                      Sector 5 Sector 6 Sector 7 Sector 8 Sector 9  \
# 0    TIC-59129133-5-FFI-30min      NaN      NaN      NaN      NaN
# 1    TIC-59091144-5-FFI-30min      NaN      NaN      NaN      NaN
# 2                         NaN      NaN      NaN      NaN      NaN
# 9                         NaN      NaN      NaN      NaN      NaN
# 21                        NaN      NaN      NaN      NaN      NaN
# ..                        ...      ...      ...      ...      ...
# 201                       NaN      NaN      NaN      NaN      NaN
# 203                       NaN      NaN      NaN      NaN      NaN
# 204                       NaN      NaN      NaN      NaN      NaN
# 205  TIC-67745212-5-FFI-30min      NaN      NaN      NaN      NaN
# 206                       NaN      NaN      NaN      NaN      NaN
#
#                       Sector 10                  Sector 11 Sector 12  \
# 0                           NaN                        NaN       NaN
# 1                           NaN                        NaN       NaN
# 2                           NaN                        NaN       NaN
# 9                           NaN                        NaN       NaN
# 21   TIC-280945693-10-FFI-30min  TIC-280945693-11-SPOC-120       NaN
# ..                          ...                        ...       ...
# 201                         NaN                        NaN       NaN
# 203                         NaN                        NaN       NaN
# 204                         NaN                        NaN       NaN
# 205                         NaN                        NaN       NaN
# 206     TIC-5714469-10-SPOC-120                        NaN       NaN
#
#     Sector 13                  Sector 14 Sector 15  Sector 16  Sector 17  \
# 0         NaN                        NaN       NaN        NaN        NaN
# 1         NaN                        NaN       NaN        NaN        NaN
# 2         NaN                        NaN       NaN        NaN        NaN
# 9         NaN                        NaN       NaN        NaN        NaN
# 21        NaN                        NaN       NaN        NaN        NaN
# ..        ...                        ...       ...        ...        ...
# 201       NaN                        NaN       NaN        NaN        NaN
# 203       NaN                        NaN       NaN        NaN        NaN
# 204       NaN  TIC-58084670-14-FFI-30min       NaN        NaN        NaN
# 205       NaN                        NaN       NaN        NaN        NaN
# 206       NaN                        NaN       NaN        NaN        NaN
#
#     Sector 18 Sector 19  Sector 20 Sector 21  Sector 22 Sector 23  Sector 24  \
# 0         NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 1         NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 2         NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 9         NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 21        NaN       NaN        NaN       NaN        NaN       NaN        NaN
# ..        ...       ...        ...       ...        ...       ...        ...
# 201       NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 203       NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 204       NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 205       NaN       NaN        NaN       NaN        NaN       NaN        NaN
# 206       NaN       NaN        NaN       NaN        NaN       NaN        NaN
#
#     Sector 25 Sector 26 Sector 27 Sector 28 Sector 29  \
# 0         NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN
# 9         NaN       NaN       NaN       NaN       NaN
# 21        NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...
# 201       NaN       NaN       NaN       NaN       NaN
# 203       NaN       NaN       NaN       NaN       NaN
# 204       NaN       NaN       NaN       NaN       NaN
# 205       NaN       NaN       NaN       NaN       NaN
# 206       NaN       NaN       NaN       NaN       NaN
#
#                      Sector 30 Sector 31                  Sector 32 Sector 33  \
# 0                          NaN       NaN  TIC-59129133-32-FFI-10min       NaN
# 1                          NaN       NaN  TIC-59091144-32-FFI-10min       NaN
# 2                          NaN       NaN                        NaN       NaN
# 9                          NaN       NaN                        NaN       NaN
# 21                         NaN       NaN                        NaN       NaN
# ..                         ...       ...                        ...       ...
# 201  TIC-244161191-30-SPOC-120       NaN                        NaN       NaN
# 203                        NaN       NaN                        NaN       NaN
# 204                        NaN       NaN                        NaN       NaN
# 205                        NaN       NaN   TIC-67745212-32-SPOC-120       NaN
# 206                        NaN       NaN                        NaN       NaN
#
#     Sector 34 Sector 35                 Sector 36                  Sector 37  \
# 0         NaN       NaN                       NaN                        NaN
# 1         NaN       NaN                       NaN                        NaN
# 2         NaN       NaN                       NaN                        NaN
# 9         NaN       NaN                       NaN                        NaN
# 21        NaN       NaN                       NaN  TIC-280945693-37-SPOC-120
# ..        ...       ...                       ...                        ...
# 201       NaN       NaN                       NaN                        NaN
# 203       NaN       NaN                       NaN                        NaN
# 204       NaN       NaN                       NaN                        NaN
# 205       NaN       NaN                       NaN                        NaN
# 206       NaN       NaN  TIC-5714469-36-FFI-10min                        NaN
#
#                      Sector 38 Sector 39  Sector 40                 Sector 41  \
# 0                          NaN       NaN        NaN                       NaN
# 1                          NaN       NaN        NaN                       NaN
# 2                          NaN       NaN        NaN                       NaN
# 9                          NaN       NaN        NaN                       NaN
# 21   TIC-280945693-38-SPOC-120       NaN        NaN                       NaN
# ..                         ...       ...        ...                       ...
# 201                        NaN       NaN        NaN                       NaN
# 203                        NaN       NaN        NaN                       NaN
# 204                        NaN       NaN        NaN  TIC-58084670-41-SPOC-120
# 205                        NaN       NaN        NaN                       NaN
# 206                        NaN       NaN        NaN                       NaN
#
#                       Sector 42                  Sector 43  \
# 0                           NaN   TIC-59129133-43-SPOC-120
# 1                           NaN   TIC-59091144-43-SPOC-120
# 2                           NaN  TIC-118769116-43-SPOC-120
# 9                           NaN                        NaN
# 21                          NaN                        NaN
# ..                          ...                        ...
# 201  TIC-244161191-42-FFI-10min                        NaN
# 203                         NaN                        NaN
# 204                         NaN                        NaN
# 205                         NaN                        NaN
# 206                         NaN                        NaN
#
#                      Sector 44 Sector 45                  Sector 46  \
# 0     TIC-59129133-44-SPOC-120       NaN                        NaN
# 1     TIC-59091144-44-SPOC-120       NaN                        NaN
# 2    TIC-118769116-44-SPOC-120       NaN                        NaN
# 9                          NaN       NaN                        NaN
# 21                         NaN       NaN                        NaN
# ..                         ...       ...                        ...
# 201                        NaN       NaN                        NaN
# 203                        NaN       NaN  TIC-301676454-46-SPOC-120
# 204                        NaN       NaN                        NaN
# 205                        NaN       NaN                        NaN
# 206                        NaN       NaN                        NaN
#
#      Sector 47 Sector 48  Sector 49 Sector 50  Sector 51  Sector 52 Sector 53  \
# 0          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 1          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 2          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 9          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 21         NaN       NaN        NaN       NaN        NaN        NaN       NaN
# ..         ...       ...        ...       ...        ...        ...       ...
# 201        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 203        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 204        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 205        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 206        NaN       NaN        NaN       NaN        NaN        NaN       NaN
#
#                     Sector 54                 Sector 55  Sector 56  Sector 57  \
# 0                         NaN                       NaN        NaN        NaN
# 1                         NaN                       NaN        NaN        NaN
# 2                         NaN                       NaN        NaN        NaN
# 9                         NaN                       NaN        NaN        NaN
# 21                        NaN                       NaN        NaN        NaN
# ..                        ...                       ...        ...        ...
# 201                       NaN                       NaN        NaN        NaN
# 203                       NaN                       NaN        NaN        NaN
# 204  TIC-58084670-54-SPOC-120  TIC-58084670-55-SPOC-120        NaN        NaN
# 205                       NaN                       NaN        NaN        NaN
# 206                       NaN                       NaN        NaN        NaN
#
#     Sector 58 Sector 59  Sector 60 Sector 61 Sector 62  \
# 0         NaN       NaN        NaN       NaN       NaN
# 1         NaN       NaN        NaN       NaN       NaN
# 2         NaN       NaN        NaN       NaN       NaN
# 9         NaN       NaN        NaN       NaN       NaN
# 21        NaN       NaN        NaN       NaN       NaN
# ..        ...       ...        ...       ...       ...
# 201       NaN       NaN        NaN       NaN       NaN
# 203       NaN       NaN        NaN       NaN       NaN
# 204       NaN       NaN        NaN       NaN       NaN
# 205       NaN       NaN        NaN       NaN       NaN
# 206       NaN       NaN        NaN       NaN       NaN
#
#                    Sector 63                  Sector 64  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 9                        NaN                        NaN
# 21                       NaN  TIC-280945693-64-SPOC-120
# ..                       ...                        ...
# 201                      NaN                        NaN
# 203                      NaN                        NaN
# 204                      NaN                        NaN
# 205                      NaN                        NaN
# 206  TIC-5714469-63-FFI-200s                        NaN
#
#                      Sector 65 Sector 66 Sector 67 Sector 68 Sector 69  \
# 0                          NaN       NaN       NaN       NaN       NaN
# 1                          NaN       NaN       NaN       NaN       NaN
# 2                          NaN       NaN       NaN       NaN       NaN
# 9                          NaN       NaN       NaN       NaN       NaN
# 21   TIC-280945693-65-SPOC-120       NaN       NaN       NaN       NaN
# ..                         ...       ...       ...       ...       ...
# 201                        NaN       NaN       NaN       NaN       NaN
# 203                        NaN       NaN       NaN       NaN       NaN
# 204                        NaN       NaN       NaN       NaN       NaN
# 205                        NaN       NaN       NaN       NaN       NaN
# 206                        NaN       NaN       NaN       NaN       NaN
#
#                      Sector 70                  Sector 71  \
# 0                          NaN   TIC-59129133-71-FFI-200s
# 1                          NaN   TIC-59091144-71-FFI-200s
# 2    TIC-118769116-70-FFI-200s  TIC-118769116-71-FFI-200s
# 9                          NaN                        NaN
# 21                         NaN                        NaN
# ..                         ...                        ...
# 201  TIC-244161191-70-SPOC-120                        NaN
# 203                        NaN                        NaN
# 204                        NaN                        NaN
# 205                        NaN                        NaN
# 206                        NaN                        NaN
#
#                      Sector 72 Sector 73                 Sector 74  \
# 0                          NaN       NaN                       NaN
# 1                          NaN       NaN                       NaN
# 2                          NaN       NaN                       NaN
# 9                          NaN       NaN                       NaN
# 21                         NaN       NaN                       NaN
# ..                         ...       ...                       ...
# 201                        NaN       NaN                       NaN
# 203  TIC-301676454-72-FFI-200s       NaN                       NaN
# 204                        NaN       NaN  TIC-58084670-74-SPOC-120
# 205                        NaN       NaN                       NaN
# 206                        NaN       NaN                       NaN
#
#                     Sector 75  Sector 76 Sector 77 Sector 78 Sector 79  \
# 0                         NaN        NaN       NaN       NaN       NaN
# 1                         NaN        NaN       NaN       NaN       NaN
# 2                         NaN        NaN       NaN       NaN       NaN
# 9                         NaN        NaN       NaN       NaN       NaN
# 21                        NaN        NaN       NaN       NaN       NaN
# ..                        ...        ...       ...       ...       ...
# 201                       NaN        NaN       NaN       NaN       NaN
# 203                       NaN        NaN       NaN       NaN       NaN
# 204  TIC-58084670-75-SPOC-120        NaN       NaN       NaN       NaN
# 205                       NaN        NaN       NaN       NaN       NaN
# 206                       NaN        NaN       NaN       NaN       NaN
#
#      Sector 80                 Sector 81  Sector 82  Sector 83  Sector 84  \
# 0          NaN                       NaN        NaN        NaN        NaN
# 1          NaN                       NaN        NaN        NaN        NaN
# 2          NaN                       NaN        NaN        NaN        NaN
# 9          NaN                       NaN        NaN        NaN        NaN
# 21         NaN                       NaN        NaN        NaN        NaN
# ..         ...                       ...        ...        ...        ...
# 201        NaN                       NaN        NaN        NaN        NaN
# 203        NaN                       NaN        NaN        NaN        NaN
# 204        NaN  TIC-58084670-81-SPOC-120        NaN        NaN        NaN
# 205        NaN                       NaN        NaN        NaN        NaN
# 206        NaN                       NaN        NaN        NaN        NaN
#
#     Sector 85 Sector 86 Sector 87 Sector 88 Sector 89  \
# 0         NaN       NaN       NaN       NaN       NaN
# 1         NaN       NaN       NaN       NaN       NaN
# 2         NaN       NaN       NaN       NaN       NaN
# 9         NaN       NaN       NaN       NaN       NaN
# 21        NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...
# 201       NaN       NaN       NaN       NaN       NaN
# 203       NaN       NaN       NaN       NaN       NaN
# 204       NaN       NaN       NaN       NaN       NaN
# 205       NaN       NaN       NaN       NaN       NaN
# 206       NaN       NaN       NaN       NaN       NaN
#
#                    Sector 90                 Sector 91 Sector 92 Sector 93  \
# 0                        NaN                       NaN       NaN       NaN
# 1                        NaN                       NaN       NaN       NaN
# 2                        NaN                       NaN       NaN       NaN
# 9                        NaN  TIC-48908525-91-FFI-200s       NaN       NaN
# 21                       NaN                       NaN       NaN       NaN
# ..                       ...                       ...       ...       ...
# 201                      NaN                       NaN       NaN       NaN
# 203                      NaN                       NaN       NaN       NaN
# 204                      NaN                       NaN       NaN       NaN
# 205                      NaN                       NaN       NaN       NaN
# 206  TIC-5714469-90-SPOC-120                       NaN       NaN       NaN
#
#      Sector 94  Sector 95  Sector 96  Sector 97  Sector 98  Sector 99  \
# 0          NaN        NaN        NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN        NaN        NaN
# 9          NaN        NaN        NaN        NaN        NaN        NaN
# 21         NaN        NaN        NaN        NaN        NaN        NaN
# ..         ...        ...        ...        ...        ...        ...
# 201        NaN        NaN        NaN        NaN        NaN        NaN
# 203        NaN        NaN        NaN        NaN        NaN        NaN
# 204        NaN        NaN        NaN        NaN        NaN        NaN
# 205        NaN        NaN        NaN        NaN        NaN        NaN
# 206        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Campaign 1                     Campaign 2  Campaign 3 Campaign 4  \
# 0           NaN                            NaN         NaN        NaN
# 1           NaN                            NaN         NaN        NaN
# 2           NaN                            NaN         NaN        NaN
# 9           NaN  EPIC-204099739-2-EVEREST-1800         NaN        NaN
# 21          NaN                            NaN         NaN        NaN
# ..          ...                            ...         ...        ...
# 201         NaN                            NaN         NaN        NaN
# 203         NaN                            NaN         NaN        NaN
# 204         NaN                            NaN         NaN        NaN
# 205         NaN                            NaN         NaN        NaN
# 206         NaN                            NaN         NaN        NaN
#
#      Campaign 5  Campaign 6  Campaign 7  Campaign 8  Campaign 9  Campaign 10  \
# 0           NaN         NaN         NaN         NaN         NaN          NaN
# 1           NaN         NaN         NaN         NaN         NaN          NaN
# 2           NaN         NaN         NaN         NaN         NaN          NaN
# 9           NaN         NaN         NaN         NaN         NaN          NaN
# 21          NaN         NaN         NaN         NaN         NaN          NaN
# ..          ...         ...         ...         ...         ...          ...
# 201         NaN         NaN         NaN         NaN         NaN          NaN
# 203         NaN         NaN         NaN         NaN         NaN          NaN
# 204         NaN         NaN         NaN         NaN         NaN          NaN
# 205         NaN         NaN         NaN         NaN         NaN          NaN
# 206         NaN         NaN         NaN         NaN         NaN          NaN
#
#      Campaign 11  Campaign 12                     Campaign 13  Campaign 14  \
# 0            NaN          NaN  EPIC-246676629-13-EVEREST-1800          NaN
# 1            NaN          NaN  EPIC-246682490-13-EVEREST-1800          NaN
# 2            NaN          NaN  EPIC-247343526-13-EVEREST-1800          NaN
# 9            NaN          NaN                             NaN          NaN
# 21           NaN          NaN                             NaN          NaN
# ..           ...          ...                             ...          ...
# 201          NaN          NaN                             NaN          NaN
# 203          NaN          NaN                             NaN          NaN
# 204          NaN          NaN                             NaN          NaN
# 205          NaN          NaN                             NaN          NaN
# 206          NaN          NaN                             NaN          NaN
#
#     Campaign 15
# 0           NaN
# 1           NaN
# 2           NaN
# 9           NaN
# 21          NaN
# ..          ...
# 201         NaN
# 203         NaN
# 204         NaN
# 205         NaN
# 206         NaN
#
# [144 rows x 124 columns]

# %%
mask6 = bestlcsfilt[sector_cols].astype(str).apply(lambda col: col.str.contains('FFI', na=True))
match_counts = mask6.sum(axis=1)
bestlcsfilt[match_counts ==0 ]
# Out:
#      pop_id          TIC  gaiadr3_source_id      epic_id       per  \
# 3         3  175594111.0       6.045819e+18  203354381.0  0.599300
# 4         4  322928171.0       6.048613e+18  203636498.0  0.779400
# 5         5  175743566.0       6.049079e+18  203821589.0  0.667700
# 6         6   98689067.0       6.049137e+18  203897692.0  0.604300
# 7         7   49072162.0       6.049979e+18  204060981.0  0.399600
# ..      ...          ...                ...          ...       ...
# 195     195   60005364.0       1.471822e+17  247857331.0  7.476200
# 197     197  160329609.0       2.886234e+18          NaN  1.012917
# 200     200  125843782.0       1.514995e+17  248131102.0  1.840417
# 202     202  231058925.0       4.719413e+18          NaN  0.369583
# 207     207  259586708.0       4.784133e+18          NaN  0.938333
#
#                  group  age_Myr    disco_paper    author  paper_year Sector 1  \
# 3       Upper Scorpius     10.0  Stauffer_2018  Stauffer        2018      NaN
# 4       Upper Scorpius     10.0  Stauffer_2018  Stauffer        2018      NaN
# 5         Rho Ophiuchi      1.0  Stauffer_2018  Stauffer        2018      NaN
# 6         Rho Ophiuchi      1.0  Stauffer_2018  Stauffer        2018      NaN
# 7       Upper Scorpius     10.0  Stauffer_2018  Stauffer        2018      NaN
# ..                 ...      ...            ...       ...         ...      ...
# 195              Field      NaN    Rebull_2020    Rebull        2020      NaN
# 197              Argus     45.0     Bouma_2024     Bouma        2024      NaN
# 200             Taurus      2.0     Bouma_2024     Bouma        2024      NaN
# 202  Tucana–Horologium     40.0     Bouma_2024     Bouma        2024      NaN
# 207            Columba     42.0     Bouma_2024     Bouma        2024      NaN
#
#                      Sector 2                  Sector 3  \
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# ..                        ...                       ...
# 195                       NaN                       NaN
# 197                       NaN                       NaN
# 200                       NaN                       NaN
# 202  TIC-231058925-2-SPOC-120  TIC-231058925-3-SPOC-120
# 207                       NaN  TIC-259586708-3-SPOC-120
#
#                      Sector 4                  Sector 5  \
# 3                         NaN                       NaN
# 4                         NaN                       NaN
# 5                         NaN                       NaN
# 6                         NaN                       NaN
# 7                         NaN                       NaN
# ..                        ...                       ...
# 195                       NaN                       NaN
# 197                       NaN                       NaN
# 200                       NaN                       NaN
# 202                       NaN                       NaN
# 207  TIC-259586708-4-SPOC-120  TIC-259586708-5-SPOC-120
#
#                      Sector 6 Sector 7 Sector 8 Sector 9 Sector 10 Sector 11  \
# 3                         NaN      NaN      NaN      NaN       NaN       NaN
# 4                         NaN      NaN      NaN      NaN       NaN       NaN
# 5                         NaN      NaN      NaN      NaN       NaN       NaN
# 6                         NaN      NaN      NaN      NaN       NaN       NaN
# 7                         NaN      NaN      NaN      NaN       NaN       NaN
# ..                        ...      ...      ...      ...       ...       ...
# 195                       NaN      NaN      NaN      NaN       NaN       NaN
# 197  TIC-160329609-6-SPOC-120      NaN      NaN      NaN       NaN       NaN
# 200                       NaN      NaN      NaN      NaN       NaN       NaN
# 202                       NaN      NaN      NaN      NaN       NaN       NaN
# 207  TIC-259586708-6-SPOC-120      NaN      NaN      NaN       NaN       NaN
#
#     Sector 12 Sector 13 Sector 14 Sector 15  Sector 16  Sector 17 Sector 18  \
# 3         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 4         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 5         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 6         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 7         NaN       NaN       NaN       NaN        NaN        NaN       NaN
# ..        ...       ...       ...       ...        ...        ...       ...
# 195       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 197       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 200       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 202       NaN       NaN       NaN       NaN        NaN        NaN       NaN
# 207       NaN       NaN       NaN       NaN        NaN        NaN       NaN
#
#     Sector 19  Sector 20 Sector 21  Sector 22 Sector 23  Sector 24 Sector 25  \
# 3         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 4         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 5         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 6         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 7         NaN        NaN       NaN        NaN       NaN        NaN       NaN
# ..        ...        ...       ...        ...       ...        ...       ...
# 195       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 197       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 200       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 202       NaN        NaN       NaN        NaN       NaN        NaN       NaN
# 207       NaN        NaN       NaN        NaN       NaN        NaN       NaN
#
#     Sector 26 Sector 27 Sector 28                  Sector 29  \
# 3         NaN       NaN       NaN                        NaN
# 4         NaN       NaN       NaN                        NaN
# 5         NaN       NaN       NaN                        NaN
# 6         NaN       NaN       NaN                        NaN
# 7         NaN       NaN       NaN                        NaN
# ..        ...       ...       ...                        ...
# 195       NaN       NaN       NaN                        NaN
# 197       NaN       NaN       NaN                        NaN
# 200       NaN       NaN       NaN                        NaN
# 202       NaN       NaN       NaN  TIC-231058925-29-SPOC-120
# 207       NaN       NaN       NaN                        NaN
#
#                      Sector 30                  Sector 31  \
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# 5                          NaN                        NaN
# 6                          NaN                        NaN
# 7                          NaN                        NaN
# ..                         ...                        ...
# 195                        NaN                        NaN
# 197                        NaN                        NaN
# 200                        NaN                        NaN
# 202  TIC-231058925-30-SPOC-120                        NaN
# 207  TIC-259586708-30-SPOC-120  TIC-259586708-31-SPOC-120
#
#                      Sector 32                  Sector 33 Sector 34 Sector 35  \
# 3                          NaN                        NaN       NaN       NaN
# 4                          NaN                        NaN       NaN       NaN
# 5                          NaN                        NaN       NaN       NaN
# 6                          NaN                        NaN       NaN       NaN
# 7                          NaN                        NaN       NaN       NaN
# ..                         ...                        ...       ...       ...
# 195                        NaN                        NaN       NaN       NaN
# 197  TIC-160329609-32-SPOC-120  TIC-160329609-33-SPOC-120       NaN       NaN
# 200                        NaN                        NaN       NaN       NaN
# 202                        NaN                        NaN       NaN       NaN
# 207  TIC-259586708-32-SPOC-120                        NaN       NaN       NaN
#
#     Sector 36 Sector 37 Sector 38 Sector 39  Sector 40 Sector 41 Sector 42  \
# 3         NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 5         NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 6         NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 7         NaN       NaN       NaN       NaN        NaN       NaN       NaN
# ..        ...       ...       ...       ...        ...       ...       ...
# 195       NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 197       NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 200       NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 202       NaN       NaN       NaN       NaN        NaN       NaN       NaN
# 207       NaN       NaN       NaN       NaN        NaN       NaN       NaN
#
#                      Sector 43                  Sector 44 Sector 45 Sector 46  \
# 3                          NaN                        NaN       NaN       NaN
# 4                          NaN                        NaN       NaN       NaN
# 5                          NaN                        NaN       NaN       NaN
# 6                          NaN                        NaN       NaN       NaN
# 7                          NaN                        NaN       NaN       NaN
# ..                         ...                        ...       ...       ...
# 195   TIC-60005364-43-SPOC-120   TIC-60005364-44-SPOC-120       NaN       NaN
# 197                        NaN                        NaN       NaN       NaN
# 200  TIC-125843782-43-SPOC-120  TIC-125843782-44-SPOC-120       NaN       NaN
# 202                        NaN                        NaN       NaN       NaN
# 207                        NaN                        NaN       NaN       NaN
#
#      Sector 47 Sector 48  Sector 49 Sector 50  Sector 51  Sector 52 Sector 53  \
# 3          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 4          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 5          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 6          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 7          NaN       NaN        NaN       NaN        NaN        NaN       NaN
# ..         ...       ...        ...       ...        ...        ...       ...
# 195        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 197        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 200        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 202        NaN       NaN        NaN       NaN        NaN        NaN       NaN
# 207        NaN       NaN        NaN       NaN        NaN        NaN       NaN
#
#     Sector 54 Sector 55  Sector 56  Sector 57 Sector 58 Sector 59  Sector 60  \
# 3         NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 4         NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 5         NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 6         NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 7         NaN       NaN        NaN        NaN       NaN       NaN        NaN
# ..        ...       ...        ...        ...       ...       ...        ...
# 195       NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 197       NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 200       NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 202       NaN       NaN        NaN        NaN       NaN       NaN        NaN
# 207       NaN       NaN        NaN        NaN       NaN       NaN        NaN
#
#     Sector 61 Sector 62 Sector 63 Sector 64 Sector 65 Sector 66 Sector 67  \
# 3         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 5         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 6         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 7         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ..        ...       ...       ...       ...       ...       ...       ...
# 195       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 197       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 200       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 202       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 207       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#     Sector 68                  Sector 69                  Sector 70  \
# 3         NaN                        NaN                        NaN
# 4         NaN                        NaN                        NaN
# 5         NaN                        NaN                        NaN
# 6         NaN                        NaN                        NaN
# 7         NaN                        NaN                        NaN
# ..        ...                        ...                        ...
# 195       NaN                        NaN                        NaN
# 197       NaN                        NaN                        NaN
# 200       NaN                        NaN  TIC-125843782-70-SPOC-120
# 202       NaN  TIC-231058925-69-SPOC-120                        NaN
# 207       NaN                        NaN                        NaN
#
#                      Sector 71 Sector 72 Sector 73 Sector 74 Sector 75  \
# 3                          NaN       NaN       NaN       NaN       NaN
# 4                          NaN       NaN       NaN       NaN       NaN
# 5                          NaN       NaN       NaN       NaN       NaN
# 6                          NaN       NaN       NaN       NaN       NaN
# 7                          NaN       NaN       NaN       NaN       NaN
# ..                         ...       ...       ...       ...       ...
# 195   TIC-60005364-71-SPOC-120       NaN       NaN       NaN       NaN
# 197                        NaN       NaN       NaN       NaN       NaN
# 200  TIC-125843782-71-SPOC-120       NaN       NaN       NaN       NaN
# 202                        NaN       NaN       NaN       NaN       NaN
# 207                        NaN       NaN       NaN       NaN       NaN
#
#      Sector 76 Sector 77 Sector 78 Sector 79  Sector 80 Sector 81  Sector 82  \
# 3          NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 4          NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 5          NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 6          NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 7          NaN       NaN       NaN       NaN        NaN       NaN        NaN
# ..         ...       ...       ...       ...        ...       ...        ...
# 195        NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 197        NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 200        NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 202        NaN       NaN       NaN       NaN        NaN       NaN        NaN
# 207        NaN       NaN       NaN       NaN        NaN       NaN        NaN
#
#      Sector 83  Sector 84 Sector 85 Sector 86                  Sector 87  \
# 3          NaN        NaN       NaN       NaN                        NaN
# 4          NaN        NaN       NaN       NaN                        NaN
# 5          NaN        NaN       NaN       NaN                        NaN
# 6          NaN        NaN       NaN       NaN                        NaN
# 7          NaN        NaN       NaN       NaN                        NaN
# ..         ...        ...       ...       ...                        ...
# 195        NaN        NaN       NaN       NaN                        NaN
# 197        NaN        NaN       NaN       NaN  TIC-160329609-87-SPOC-120
# 200        NaN        NaN       NaN       NaN                        NaN
# 202        NaN        NaN       NaN       NaN                        NaN
# 207        NaN        NaN       NaN       NaN                        NaN
#
#     Sector 88 Sector 89 Sector 90                  Sector 91 Sector 92  \
# 3         NaN       NaN       NaN  TIC-175594111-91-SPOC-120       NaN
# 4         NaN       NaN       NaN  TIC-322928171-91-SPOC-120       NaN
# 5         NaN       NaN       NaN  TIC-175743566-91-SPOC-120       NaN
# 6         NaN       NaN       NaN   TIC-98689067-91-SPOC-120       NaN
# 7         NaN       NaN       NaN   TIC-49072162-91-SPOC-120       NaN
# ..        ...       ...       ...                        ...       ...
# 195       NaN       NaN       NaN                        NaN       NaN
# 197       NaN       NaN       NaN                        NaN       NaN
# 200       NaN       NaN       NaN                        NaN       NaN
# 202       NaN       NaN       NaN                        NaN       NaN
# 207       NaN       NaN       NaN                        NaN       NaN
#
#     Sector 93  Sector 94  Sector 95  Sector 96  Sector 97  Sector 98  \
# 3         NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN        NaN        NaN        NaN        NaN        NaN
# 5         NaN        NaN        NaN        NaN        NaN        NaN
# 6         NaN        NaN        NaN        NaN        NaN        NaN
# 7         NaN        NaN        NaN        NaN        NaN        NaN
# ..        ...        ...        ...        ...        ...        ...
# 195       NaN        NaN        NaN        NaN        NaN        NaN
# 197       NaN        NaN        NaN        NaN        NaN        NaN
# 200       NaN        NaN        NaN        NaN        NaN        NaN
# 202       NaN        NaN        NaN        NaN        NaN        NaN
# 207       NaN        NaN        NaN        NaN        NaN        NaN
#
#      Sector 99  Campaign 1                     Campaign 2  Campaign 3  \
# 3          NaN         NaN  EPIC-203354381-2-EVEREST-1800         NaN
# 4          NaN         NaN  EPIC-203636498-2-EVEREST-1800         NaN
# 5          NaN         NaN  EPIC-203821589-2-EVEREST-1800         NaN
# 6          NaN         NaN  EPIC-203897692-2-EVEREST-1800         NaN
# 7          NaN         NaN  EPIC-204060981-2-EVEREST-1800         NaN
# ..         ...         ...                            ...         ...
# 195        NaN         NaN                            NaN         NaN
# 197        NaN         NaN                            NaN         NaN
# 200        NaN         NaN                            NaN         NaN
# 202        NaN         NaN                            NaN         NaN
# 207        NaN         NaN                            NaN         NaN
#
#     Campaign 4  Campaign 5  Campaign 6  Campaign 7  Campaign 8  Campaign 9  \
# 3          NaN         NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...         ...
# 195        NaN         NaN         NaN         NaN         NaN         NaN
# 197        NaN         NaN         NaN         NaN         NaN         NaN
# 200        NaN         NaN         NaN         NaN         NaN         NaN
# 202        NaN         NaN         NaN         NaN         NaN         NaN
# 207        NaN         NaN         NaN         NaN         NaN         NaN
#
#      Campaign 10  Campaign 11  Campaign 12                     Campaign 13  \
# 3            NaN          NaN          NaN                             NaN
# 4            NaN          NaN          NaN                             NaN
# 5            NaN          NaN          NaN                             NaN
# 6            NaN          NaN          NaN                             NaN
# 7            NaN          NaN          NaN                             NaN
# ..           ...          ...          ...                             ...
# 195          NaN          NaN          NaN  EPIC-247857331-13-EVEREST-1800
# 197          NaN          NaN          NaN                             NaN
# 200          NaN          NaN          NaN  EPIC-248131102-13-EVEREST-1800
# 202          NaN          NaN          NaN                             NaN
# 207          NaN          NaN          NaN                             NaN
#
#      Campaign 14 Campaign 15
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# ..           ...         ...
# 195          NaN         NaN
# 197          NaN         NaN
# 200          NaN         NaN
# 202          NaN         NaN
# 207          NaN         NaN
#
# [62 rows x 124 columns]
